# %%
import random

SumValue = "junk"

random_number = random.randint(1,6)
balls = 60 
ballsBat = 0
playerRuns = 0
balls2 = 60
ballsBat2 = 0
compRuns2 = 0
balls3 = 60
ballsBat3 = 0
compRuns3 = 0
balls4 = 60
ballsBat4 = 0
playerRuns4 = 0
        
toss = input("Choose between Odd(o) or Even(e): ").lower()      #toss selection
tossNum = int(input("Please select a number between 1 to 6: "))  #number selection 

if (tossNum>6 or tossNum<1):     #error checking 
    print("Invalid input")
else:
    print(f'You have chosen {tossNum} and the computer have chosen {random_number}') #printing the selection
    sumToss = tossNum + random_number  
    
if (sumToss%2 == 0):    #step for calculating odd or even
    SumValue = 'e'      #variable assigned for odd or even later used for bat/bowl selection
    print("It is even")
else:
    SumValue = 'o'
    print("It is odd")

if SumValue == toss:
    batbowl = input('You have won the toss, would you like to bat(b) or bowl(bo): ')
    
    #player won toss and chose to bat first
    #1st Innings
    if batbowl == 'b':
        balls = 60  #10 overs, each over 6 balls, total 60balls
        ballsBat = 0
        playerRuns = 0
        print('------\nYour Batting----\n')
        while ballsBat < balls:
            runs = int(input("Enter a number to bat from 1 to 6: ")) #user input number for batting
            compBowl = random.randint(1,6) #computer input number for bowling
        
        #comparing runs and compBowl for determining: out
            if runs == compBowl: #checks if initial numbers are equal then: out
                print(f"Your number is {runs} and Computer's number is {compBowl}" )
                print(f"You are out.Your total Score  is {playerRuns}")
                break
            elif runs>6:
                print("Invalid input,Please enter numbers from 1 to 6")
                continue
            else:
                playerRuns += runs
                print(f"Your number: {runs},computer's number {compBowl} ")
                print(f"Your runs are {playerRuns}\n")

            ballsBat+= 1   
           
        #computer's Batting
        #2nd Innings
        print("--------\nComputer's Batting-------\n")
        balls2 = 60
        ballsBat2 = 0
        compRuns2 = 0
        while ballsBat2 < balls2:
            bowl2 = int(input("Enter number to bowl from 1 to 6: "))
            compBat2 = random.randint(1,6)
            
            if compBat2 == bowl2:
                print(f"Computer's number is {compBat2}, Your number is {bowl2}")
                print(f"computer is out. Computer's total score is {compRuns2}")
                break
            else:
                compRuns2 += compBat2
                print(f"Computer's number is {compBat2},Your number is {bowl2}")
                print(f"Computer Score is {compRuns2}\n")
                
                if compRuns2 > playerRuns:
                    break
            ballsBat2 += 1        
            
        #Result
        print("______\nRESULT: ")
        
        if compRuns2 < playerRuns:                                                     #+1 is used to get the total balls occured
            print(f"\nYou have won the game. \n\n Your total runs are {playerRuns} in {ballsBat+1} balls and the computer scored {compBat2} in {ballsBat2+1} balls") 
        elif compRuns2 == playerRuns:
            print(f"The game is a tie, You score {playerRuns} and the computer scored {compRuns2}")
        
        else:
            print(f"\nComputer won the game. \n\nComputer's total runs are {compRuns2} in {ballsBat2+1} and you scored {playerRuns} in {ballsBat+1} balls")
            
    #User selected to bowl first
    #1st Innings computer's Batting
    if batbowl == 'bo':
        print("--------\nComputer batting\n")
        balls3 = 60
        ballsBat3 = 0
        compRuns3 = 0
        while ballsBat3 < balls3:
            bowl3 = int(input("Enter number to bowl from 1 to 6: "))
            compBat3 = random.randint(1,6)
            
            if compBat3 == bowl3:
                print(f"Computer's number is {compBat3} and your number is {bowl3}")
                print(f"Computer is out. Computer's total score is {compRuns3}")
                break
            else:
                compRuns3 += compBat3 #random number generated by computer itself..so incremented like this
                print(f"Computer's number is {compBat3} and your number is {bowl3}")
                print(f"Computer's total score is {compRuns3}\n")
            ballsBat3 += 1    
            
        #2nd Innings User's Batting
        balls4 = 60
        ballsBat4 = 0
        playerRuns4 = 0
        print("----------\nYour Batting\n")


        while  ballsBat4 < balls4:
            runs4 = int(input("Enter a number to bat from 1 to 6: "))
            compBowl4 = random.randint(1,6)

            if runs4 == compBowl4:
                print(f"Your number is {runs4} and computer's number is {compBowl4}")
                print(f"You are Out.Your total score is {playerRuns4}\n")
                break
            elif runs4 > 6:
                print(f"Invalid Input. Please enter numbers from 1 to 6")
                continue
            else:
                playerRuns4 += runs4
                print(f"Your number: {runs4},computer's number:{compBowl4}")
                print(f"Your total score is {playerRuns4}\n")

                if playerRuns4 > compRuns3:
                    break
            ballsBat4 += 1

        print("-----------\nResult")

        if compRuns3 < playerRuns4:
            print(f"You have won the game.\n\nYour total runs are {playerRuns4} in {ballsBat4+1} balls. Computer's total score is {compRuns3} in {ballsBat3+1} balls ")
        elif compRuns3 == playerRuns4:
            print(f"The game is Tie, Your score is {playerRuns4} and computer's score is {compRuns3}")
        else:
            print(f"\nComputer won the game.\n\nComputer's total runs are {compRuns3} in {ballsBat3+1} balls. Your runs are {playerRuns4} in {ballsBat4+1} balls")


#computer choose to bat first   
#1st innings
else:
    print("Computer won the toss and chooses to bat first")
    print("_____\nComputer Batting\n")
    balls3 = 60
    ballsBat3 = 0
    compRuns3 = 0
    while ballsBat3 < balls3:
        bowl3 = int(input("Enter a number from 1 to 6 to bowl: "))
        compBat3 = random.randint(1,6)
        
        if compBat3 == bowl3:
            print(f"Computer's number is {compBat3}, Your number is {bowl3}")
            print(f"Computer is out. Computer's total score is {compRuns3} from {ballsBat3+1} balls")
            break
        else:
            compRuns3 += compBat3
            print(f"Computer's number is {compBat3}, Your number is {bowl3}")
            print(f"Computer's Total Score is {compRuns3}\n")
        ballsBat3 += 1    
    
    #2ND INNINGS
    balls4 = 60
    ballsBat4 = 0
    playerRuns4 = 0
    
    print("---------\nYour Batting\n")
    while ballsBat4 < balls:
        runs4 = int(input("Enter a number from 1 to 6 to bat: "))
        compBowl4 = random.randint(1,6)
        
        if runs4 == compBowl4:
            print(f"Your number is {runs4}, Computer's number is {compBowl4}")
            print(f"You are out. Your total score is {playerRuns4} in {ballsBat4 +1} balls\n")
            break
        elif runs4>6:
            print("Invalid input.Enter a Value from 1 to 6")
            continue
        else:
            playerRuns4 += runs4
            print(f"Your number is {runs4}, Computer's number is {compBowl4}")
            print(f"Your Total score is {playerRuns4} in {ballsBat4 + 1} balls\n")
            
            if playerRuns4 > compRuns3:
                break
        ballsBat4 += 1
        
    print("------------\nRESULT")

    if compRuns3 < playerRuns4:
        print(f"\nYou have won the game.\n\n Your total runs are {playerRuns4} in {ballsBat4 + 1} balls and Computer scored {compRuns3} runs from {ballsBat3+1} balls")
    elif compRuns3 == playerRuns4:
        print(f"The game is tie. You Scored {playerRuns4} and computer scored {compRuns3}")
    else:
        print(f"\nComputer won the game.\n\nComputer scored {compRuns3} runs from {ballsBat3+1} balls and You scored {playerRuns4} runs in {ballsBat4 + 1} balls")
# Out:
# Choose between Odd(o) or Even(e): e
# Please select a number between 1 to 6: 2
# You have chosen 2 and the computer have chosen 1
# It is odd
# Computer won the toss and chooses to bat first
# _____
# Computer Batting
#
# Enter a number from 1 to 6 to bowl: 6
# Computer's number is 6, Your number is 6
# Computer is out. Computer's total score is 0 from 1 balls
# ---------
# Your Batting
#
# Enter a number from 1 to 6 to bat: 1
# Your number is 1, Computer's number is 2
# Your Total score is 1 in 1 balls
#
# ------------
# RESULT
#
# You have won the game.
#
#  Your total runs are 1 in 1 balls and Computer scored 0 runs from 1 balls
